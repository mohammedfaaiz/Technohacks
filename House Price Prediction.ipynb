# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("train.csv", index_col="Id")
test_df = pd.read_csv("test.csv", index_col="Id")
df = pd.concat([df_train, df_test])

# %%
train_df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_df.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
# ...

# %%
train_df.shape
# Out:
# (1460, 80)

# %%
test_df.shape
# Out:
# (1459, 79)

# %%
train_df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# ...

# %%
test_df.describe().T
# Out:
#                 count         mean          std     min      25%     50%  \
# MSSubClass     1459.0    57.378341    42.746880    20.0    20.00    50.0
# LotFrontage    1232.0    68.580357    22.376841    21.0    58.00    67.0
# LotArea        1459.0  9819.161069  4955.517327  1470.0  7391.00  9399.0
# OverallQual    1459.0     6.078821     1.436812     1.0     5.00     6.0
# OverallCond    1459.0     5.553804     1.113740     1.0     5.00     5.0
# YearBuilt      1459.0  1971.357779    30.390071  1879.0  1953.00  1973.0
# YearRemodAdd   1459.0  1983.662783    21.130467  1950.0  1963.00  1992.0
# MasVnrArea     1444.0   100.709141   177.625900     0.0     0.00     0.0
# BsmtFinSF1     1458.0   439.203704   455.268042     0.0     0.00   350.5
# BsmtFinSF2     1458.0    52.619342   176.753926     0.0     0.00     0.0
# BsmtUnfSF      1458.0   554.294925   437.260486     0.0   219.25   460.0
# TotalBsmtSF    1458.0  1046.117970   442.898624     0.0   784.00   988.0
# ...

# %%
print("\nMissing Values in Train Dataset:")
print(train_df.isnull().sum())

print("\nMissing Values in Test Dataset:")
print(test_df.isnull().sum())
# Out:
# Missing Values in Train Dataset:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64
#
# Missing Values in Test Dataset:
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
# Street             0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 79, dtype: int64

# %%
sns.heatmap(train_df.isnull())
# Out:
# <AxesSubplot:ylabel='Id'>

# %%
sns.heatmap(test_df.isnull())
# Out:
# <AxesSubplot:ylabel='Id'>

# %%
train_df.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.386347 -0.139781     0.032628    -0.059316
# LotFrontage     -0.386347     1.000000  0.426095     0.251646    -0.059213
# LotArea         -0.139781     0.426095  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.251646  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.059213 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.123349  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.088866  0.013788     0.550684     0.073741
# MasVnrArea       0.022936     0.193458  0.104160     0.411876    -0.128101
# BsmtFinSF1      -0.069836     0.233633  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.049900  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.132644 -0.002618     0.308159    -0.136841
# ...

# %%
test_df.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.450505 -0.359537     0.034690    -0.071768
# LotFrontage     -0.450505     1.000000  0.644608     0.182870    -0.092312
# LotArea         -0.359537     0.644608  1.000000     0.107989    -0.103402
# OverallQual      0.034690     0.182870  0.107989     1.000000    -0.095874
# OverallCond     -0.071768    -0.092312 -0.103402    -0.095874     1.000000
# YearBuilt        0.040848     0.122356  0.048314     0.621910    -0.361027
# YearRemodAdd     0.046319     0.092603  0.036907     0.591267     0.021668
# MasVnrArea      -0.012186     0.251533  0.188691     0.453991    -0.144261
# BsmtFinSF1      -0.058775     0.204621  0.185470     0.322583    -0.054720
# BsmtFinSF2      -0.079093     0.046824  0.054199    -0.028199     0.043109
# BsmtUnfSF       -0.111080     0.092031  0.071681     0.243070    -0.139927
# ...

# %%
sns.histplot(train_df["SalePrice"], kde=True)
plt.title("Distribution of SalePrice")
plt.xlabel("SalePrice")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr())
plt.title("Correlations Between Variables", size=15)
plt.show()

# %%
sns.scatterplot(data=df, x="GrLivArea", y="SalePrice")
plt.title("GrLivArea vs. SalePrice")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.jointplot(x=df["OverallQual"], y=df["SalePrice"])
plt.show()

# %%
important_num_cols = list(df.corr()["SalePrice"][(df.corr()["SalePrice"]>0.50) | (df.corr()["SalePrice"]<-0.50)].index)
cat_cols = ["MSZoning", "Utilities","BldgType","Heating","KitchenQual","SaleCondition","LandSlope"]
important_cols = important_num_cols + cat_cols

df = df[important_cols]

# %%
sns.pairplot(df[important_num_cols])

# %%
# Concatenating train and test data for preprocessing
combined_data = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
# Handling missing values
combined_data["LotFrontage"].fillna(combined_data["LotFrontage"].median(), inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Encoding categorical variables
categorical_cols = ["MSZoning", "Street", "Alley", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope",
                    "Neighborhood", "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl",
                    "Exterior1st", "Exterior2nd", "MasVnrType", "ExterQual", "ExterCond", "Foundation", "BsmtQual",
                    "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "Heating", "HeatingQC", "CentralAir",
                    "Electrical", "KitchenQual", "Functional", "FireplaceQu", "GarageType", "GarageFinish",
                    "GarageQual", "GarageCond", "PavedDrive", "PoolQC", "Fence", "MiscFeature", "SaleType",
                    "SaleCondition"]

for col in categorical_cols:
    combined_data[col] = combined_data[col].fillna("None")
    label_encoder = LabelEncoder()
    combined_data[col] = label_encoder.fit_transform(combined_data[col])
    
# Scale numerical features
numerical_cols = ["LotFrontage", "LotArea", "OverallQual", "OverallCond", "YearBuilt", "YearRemodAdd", "MasVnrArea",
                  "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "LowQualFinSF",
                  "GrLivArea", "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath", "BedroomAbvGr", "KitchenAbvGr",
                  "TotRmsAbvGrd", "Fireplaces", "GarageCars", "GarageArea", "WoodDeckSF", "OpenPorchSF",
                  "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea", "MiscVal", "MoSold", "YrSold"]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
combined_data[numerical_cols] = scaler.fit_transform(combined_data[numerical_cols])

# %%
# Split the data back into train and test datasets
train_df = combined_data[:train_df.shape[0]]
test_df = combined_data[train_df.shape[0]:]

# Split the train dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_df.drop("SalePrice", axis=1), train_df["SalePrice"],
test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.tree import export_graphviz
from IPython.display import Image

# %%
# Dropping rows with missing values from the training set
X_train.dropna(inplace=True)
y_train = y_train[X_train.index]

# Dropping rows with missing values from the validation set
X_val.dropna(inplace=True)
y_val = y_val[X_val.index]  # Align the target variable

# Creating an imputer to replace missing values with the mean
imputer = SimpleImputer(strategy="mean")

# Fitting the imputer on the training set and transform both training and validation sets
X_train_imputed = imputer.fit_transform(X_train)
X_val_imputed = imputer.transform(X_val)

# %% [markdown]
# # Random Forest

# %%
# Creating a Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=300, random_state=42)

# %%
# Training the model on the imputed training set
rf_model.fit(X_train_imputed, y_train)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
# Predicting on the imputed validation set
y_val_pred = rf_model.predict(X_val_imputed)

# %%
# Evaluating the model
rmse = mean_squared_error(y_val, y_val_pred, squared=False)
print("Root Mean Squared Error (RMSE) on validation set:", rmse)
# Out:
# Root Mean Squared Error (RMSE) on validation set: 29666.742037933585

# %% [markdown]
# # Model Evaluation

# %%
# Transforming the target variable using logarithm
y_train_log = np.log1p(y_train)
y_val_log = np.log1p(y_val)

# %%
# Training the model on the transformed target variable
rf_model.fit(X_train_imputed, y_train_log)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
# Predicting on the imputed validation set
y_val_pred_log = rf_model.predict(X_val_imputed)

# %%
# Transforming the predicted values back to original scale
y_val_pred = np.expm1(y_val_pred_log)

# %%
# Evaluating the model using RMSE on the original scale
rmse = mean_squared_error(y_val, y_val_pred, squared=False)
print("Root Mean Squared Error (RMSE) on validation set:", rmse)
# Out:
# Root Mean Squared Error (RMSE) on validation set: 30063.584178374316

# %%
from sklearn import metrics
metrics.mean_squared_error(y_val_pred, y_val)
# Out:
# 903819093.6501986

# %%
metrics.r2_score(y_val_pred, y_val)
# Out:
# 0.8255153807855639

# %%
plt.scatter(y_val_pred, y_val)
